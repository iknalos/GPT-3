# %%
import config
import openai

# %%
openai.api_key="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"

# %% [markdown]
# # Testing GPT-3 For Text Generation.

# %%
myPrompt =" Pardi is a place in india"

# %%
myTokens= 61
myEngine="davinci"
myTemp= 0  # Ranges from 0-1. 0 being factual information.
myTop_p=1 #an alternative way of controlling the randomness and creativity of the text generated by GPT-3
myN=1
myStream= None
myLogProbs= None
myStop=["\n\n\n\n\n\n\n"]

# %%
response = openai.Completion.create(
  engine=myEngine,
  prompt=myPrompt,
  max_tokens=myTokens,
  temperature=myTemp,
  top_p=myTop_p,
  n=myN,
  stream = myStream,
  logprobs=myLogProbs,
  stop = myStop
)

print(f"{myPrompt}\n{response.choices[0].text}")
# Out:
#  Pardi is a place in india
# , where the people are very friendly and helpful. The people are very helpful and friendly. The people are very helpful and friendly. The people are very helpful and friendly. The people are very helpful and friendly. The people are very helpful and friendly. The people are very helpful and friendly. The people are

# %% [markdown]
# # Sentiment Analysis few shots encoding.

# %%
import os
import openai
openai.api_key = "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"
response = openai.Completion.create(
engine="davinci",prompt="This is a Sentence sentiment classifier\n\n\nSentence: 
    \"I loved the new Batman movie!\"\nSentiment: Positive\n###\nSentence: 
    \"I hate it when my phone battery dies.\"\nSentiment: Negative\n###\nSentence: 
    \"My day has been 👍\"\nSentiment: Positive\n###\nSentence: 
    \"This is the link to the article\"\nSentiment: Neutral\n###\nSentence: 
    \"This new music video blew my mind\"\nSentiment:",temperature=0.3,
max_tokens=60,
top_p=1.0,
frequency_penalty=0.5,
presence_penalty=0.0,
stop=["###"])
print (response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Positive\n"
#     }
#   ],
#   "created": 1657041883,
#   "id": "cmpl-5QgZvyrKfLJlVdSijGqZSBXn5xI3N",
#   "model": "davinci",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 8,
#     "prompt_tokens": 105,
#     "total_tokens": 113
#   }
# }

# %% [markdown]
# # English to Gujarati conversion

# %%
#ResponseLength - To control How much text is 
#Frequency_penalty - limits the repeatation of words.
#presence_penalty - prevent topic repeatations.

# %%
import os
import openai
openai.api_key = "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"
response = openai.Completion.create(
engine="davinci",
prompt="This is a Language Translator\n\n\nSentence: \My Name is Rahul: મારું નામ રાહુલ છે\n###\nSentence: \I am from India: હું ભારતનો છું\n###\nSentence: \What is your name?:",
temperature=1,
max_tokens=60,
top_p=0,
n=1,
frequency_penalty=0.0,
presence_penalty=0.0,
stop=["###"])
print(response.choices[0].text)
# Out:
#  તો તમારી નામ કેવી છે?

# %% [markdown]
# # More generalized Text Generation for a specific company

# %%
import ipywidgets as widgets

# %%
company_name = widgets.Text(value='Rahul Badminton Co.', disabled=False,description='Name')
headquarters_location = widgets.Text(value='Cambridge, United States', disabled=False,description='Location')
industries = widgets.Text(value='Badminton Stringing Service', disabled=False,description='Business')
display(company_name,headquarters_location,industries)
# Out:
# Text(value='Rahul Badminton Co.', description='Name')
# Text(value='Cambridge, United States', description='Location')
# Text(value='Badminton Stringing Service', description='Business')

# %%
myEntry = f"""full name of company:{company_name.value}\nheadquarters location:{headquarters_location.value}\nindustries:{industries.value}"""

# %%
#Custom text input
myPrompt = f"""Generates everything that a new business needs to get started connecting with their audience. 

full name of company:Apple Computer Inc.
headquarters location:USA
industries: Computer hardware,Computer software,Consumer electronics,Cloud computing,Digital distribution,Fabless silicon design,Semiconductors,Media,Financial technology,Artificial intelligence
geographical focus:global
contact:8152829991
philosophy:make the best products
logo concept: an apple with a bite taken out of it. Black. No text.
company colors: black and white
slogan:Think Different
3 product ideas:portable music player, online music store, web application store
1 free tweet: '''Apple Computer today unveiled its much-anticipated Macintosh computer, a sophisticated, affordably priced personal computer designed for business people, professionals and students in a broad range of fields.'''
3 geographic targets:United States, Canada, United Kingdom

{myEntry}
"""

# %%
#parameters
myTokens = 350
myEngine = "davinci"
myTemp = 0.5
myTop_p = 1
myN=1
myStream = None
myLogProbs = None
myStop = "\n\n"

# %%
response = openai.Completion.create(
  engine=myEngine,
  prompt=myPrompt,
  max_tokens=myTokens,
  temperature=myTemp,
  top_p=myTop_p,
  n=myN,
  stream = myStream,
  logprobs=myLogProbs,
  best_of=1,
  stop = myStop
)

print(f"{myEntry}\n{response.choices[0].text}")
# Out:
# full name of company:Rahul Badminton Co.
# headquarters location:Cambridge, United States
# industries:Badminton Stringing Service
# geographical focus:North America
# contact:617-555-1212
# philosophy:Play Badminton, Love Badminton, Play Badminton with love, Play Badminton with passion, Play Badminton with Rahul Badminton
# slogan:Play Badminton with Rahul Badminton
# 3 product ideas:Badminton Stringing Service, Badminton Stringing Machine, Badminton Stringing Machine with a Stringing Machine
# 1 free tweet: '''Rahul Badminton, the world's leading badminton stringing company, today announced that it has developed a new, patent-pending stringing machine that will dramatically increase its production capacity.'''
# 3 geographic targets:United States, Canada, United Kingdom

# %% [markdown]
# # Text Summarization

# %%
3 # Load your PDF
file = open("gpt_e.pdf")

# %%
pip install pdfplumber
# Out:
# ...
#   Created wheel for pdfplumber: filename=pdfplumber-0.6.0-py3-none-any.whl size=33668 sha256=ba46ee1b8e8e7ed43f05d049b1a5f3bdc6d5d35de986e47561123e44e586f4e8
#   Stored in directory: c:\users\solan\appdata\local\pip\cache\wheels\58\56\fe\2e93d842ffa9ea97746c1ab253d43502ed61c0689361a0224e
# Successfully built pdfplumber
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: imageai 2.1.6 has requirement pillow==7.0.0, but you'll have pillow 9.0.1 which is incompatible.

# %%
import pdfplumber
with pdfplumber.open(r'C:\Users\solan\Downloads\Sensorymapsintheolfactorycortex.pdf') as pdf:
    first_page = pdf.pages[0]
    print(first_page.extract_text())
# Out:
# LETTER
# doi:10.1038/nature09945
# Sensory maps in the olfactory cortex defined by
# long-range viral tracing of single neurons
# SulagnaGhosh1,StephenD.Larson2,HoomanHefzi1,ZacharyMarnoy1,TylerCutforth3,KartheekDokka1&KristinK.Baldwin1
# Sensoryinformationmayberepresentedinthebrainbystereotyped ofMTaxonsinthecortexretainsaspectsoftheglomerularorganization
# mappingofaxonalinputsorbypatterningthatvariesbetweenindi- oftheOB,orwhethersensorymapsinthecortexarestereotypedor
# viduals.Inolfaction,astereotypedmapisevidentinthefirstsensory divergentbetweenindividuals(SupplementaryFig.1).
# processingcentre,theolfactorybulb(OB),wheredifferentodours Onebarriertomappingolfactoryneuralcircuitsisthelackoflong-
# elicitactivityinuniquecombinatorialpatternsofspatiallyinvariant rangeaxontracingmethodsthatdonotobscuretheglomerulariden-
# glomeruli1,2.Activationofeachglomerulusisrelayedtohighercor- tityoftheMTneuron.Wehavedevelopedaviraltracingsystemthat
# ...

# %%
import os
import openai
openai.api_key = "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"
tldr_tag = "\n tl;dr:" # this tex is used for summary.
text=first_page.extract_text() + tldr_tag
response = openai.Completion.create(
engine="davinci",
prompt= text,
temperature=1,
n=1,
top_p=0,
max_tokens=100,
frequency_penalty=0.0,
presence_penalty=0.0,
stop=["\n"])
print(response.choices[0].text)
# Out:
#  The olfactory bulb is a stereotyped map of odorants, but the cortical targets of the olfactory bulb are not stereotyped.

# %%
print(f"{response.choices[0].text}")
# Out:
#  The olfactory bulb is a stereotyped map of odorants, but the cortical targets of the same neurons are not.
